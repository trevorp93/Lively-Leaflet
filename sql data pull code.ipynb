# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

engine = create_engine("sqlite:///restaurantdata.sqlite", echo=False)

inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['restaurants']

# %%
df = pd.DataFrame(datatest, columns=['businesses__id','businesses__name','businesses__image_url','businesses__is_closed',
                                     'businesses__url','businesses__review_count','businesses__categories__alias',
                                     'businesses__categories__title','businesses__rating','businesses__coordinates__latitude',
                                     'businesses__coordinates__longitude','businesses__transactions__001',
                                     'businesses__transactions__002','businesses__transactions__003','businesses__price',
                                     'businesses__location__address1','businesses__location__address2',
                                     'businesses__location__address3','businesses__location__city',
                                     'businesses__location__zip_code','businesses__location__country',
                                     'businesses__location__state','businesses__location__display_address__001',
                                     'businesses__location__display_address__002','businesses__location__display_address__003',
                                     'businesses__phone','businesses__display_phone','businesses__distance','total',
                                     'region__center__longitude','region__center__latitude'
])

# %%
# Out:
#   businesses__id               businesses__name businesses__image_url  \
# 0       16758591                    Toloache 50                  None
# 1       16758697                  5 Burro Caf̩                  None
# 2       16758999           Adrienne's Pizza Bar                  None
# 3       16759326                           Amma                  None
# 4       16759669  Artisanal Fromagerie & Bistro                  None
#
#   businesses__is_closed                                    businesses__url  \
# 0                  None  https://www.zomato.com/new-york-city/toloache-...
# 1                  None  https://www.zomato.com/new-york-city/5-burro-c...
# 2                  None  https://www.zomato.com/new-york-city/adriennes...
# 3                  None  https://www.zomato.com/new-york-city/amma-turt...
# 4                  None  https://www.zomato.com/new-york-city/artisanal...
#
#    businesses__review_count businesses__categories__alias  \
# ...

# %%
# Out:
# (416, 31)
